# %%
# Import pandas
import pandas as pd
 
# reading csv file
pd.read_csv("/Users/owner/Downloads/Dry_Creek_Experimental_Watershed_Lower_Deer_Point_Weather_Station_Pits_1_2_3_Hourly_Soil_Data_JMcNamara.csv", skiprows=20, header=1)
# Out:
#                DateTime   SoilMoisturePit1-vol  SoilMoisturePit2-vol  \
# 0         1/1/2007 0:00              -6999.000             -6999.000
# 1         1/1/2007 1:00              -6999.000             -6999.000
# 2         1/1/2007 2:00              -6999.000             -6999.000
# 3         1/1/2007 3:00              -6999.000             -6999.000
# 4         1/1/2007 4:00              -6999.000             -6999.000
# 5         1/1/2007 5:00              -6999.000             -6999.000
# 6         1/1/2007 6:00              -6999.000             -6999.000
# 7         1/1/2007 7:00              -6999.000             -6999.000
# 8         1/1/2007 8:00              -6999.000             -6999.000
# 9         1/1/2007 9:00              -6999.000             -6999.000
# 10       1/1/2007 10:00              -6999.000             -6999.000
# 11       1/1/2007 11:00              -6999.000             -6999.000
# 12       1/1/2007 12:00              -6999.000             -6999.000
# ...
